# %% [markdown]
# <H1>Reading GoPro video metadata using ffmepg

# %%
import matplotlib.pyplot as plt
from IPython.display import Image
# %matplotlib inline

import ffmpeg
import sys
from pprint import pprint # for printing Python dictionaries in a human-readable way

# %%
# read the audio/video file from the command line arguments
media_path = "../data/"
media_file = "../data/GH010341.MP4"
#media_file = sys.argv[1]

#os.chdir(media_path)

# uses ffprobe command to extract all possible metadata from the media file
metadata = ffmpeg.probe(media_file)["streams"]
pprint(metadata)
# Out:
# [{'avg_frame_rate': '25/1',
#   'bit_rate': '59706504',
#   'bits_per_raw_sample': '8',
#   'chroma_location': 'left',
#   'closed_captions': 0,
#   'codec_long_name': 'H.264 / AVC / MPEG-4 AVC / MPEG-4 part 10',
#   'codec_name': 'h264',
#   'codec_tag': '0x31637661',
#   'codec_tag_string': 'avc1',
#   'codec_time_base': '1/50',
#   'codec_type': 'video',
#   'coded_height': 2160,
#   'coded_width': 3840,
#   'color_primaries': 'bt709',
#   'color_range': 'pc',
#   'color_space': 'bt709',
#   'color_transfer': 'bt709',
#   'display_aspect_ratio': '16:9',
#   'disposition': {'attached_pic': 0,
#                   'clean_effects': 0,
#                   'comment': 0,
#                   'default': 1,
#                   'dub': 0,
#                   'forced': 0,
#                   'hearing_impaired': 0,
#                   'karaoke': 0,
#                   'lyrics': 0,
#                   'original': 0,
#                   'timed_thumbnails': 0,
#                   'visual_impaired': 0},
#   'duration': '305.200000',
#   'duration_ts': 27468000,
#   'has_b_frames': 0,
#   'height': 2160,
#   'index': 0,
#   'is_avc': 'true',
#   'level': 51,
#   'nal_length_size': '4',
#   'nb_frames': '7630',
#   'pix_fmt': 'yuvj420p',
#   'profile': 'High',
#   'r_frame_rate': '25/1',
#   'refs': 1,
#   'sample_aspect_ratio': '1:1',
#   'side_data_list': [{'displaymatrix': '\n'
#                                        '00000000:       -65536           '
#                                        '0           0\n'
#                                        '00000001:            0      '
#                                        '-65536           0\n'
#                                        '00000002:    251658240   141557760  '
#                                        '1073741824\n',
#                       'rotation': -180,
#                       'side_data_type': 'Display Matrix'}],
#   'start_pts': 0,
#   'start_time': '0.000000',
#   'tags': {'creation_time': '2024-12-11T10:59:19.000000Z',
#            'encoder': 'GoPro AVC encoder',
#            'handler_name': '\x0bGoPro AVC  ',
#            'language': 'eng',
#            'rotate': '180',
#            'timecode': '10:59:19:15'},
#   'time_base': '1/90000',
#   'width': 3840},
#  {'avg_frame_rate': '0/0',
#   'bit_rate': '189277',
#   'bits_per_sample': 0,
#   'channel_layout': 'stereo',
#   'channels': 2,
#   'codec_long_name': 'AAC (Advanced Audio Coding)',
#   'codec_name': 'aac',
#   'codec_tag': '0x6134706d',
#   'codec_tag_string': 'mp4a',
#   'codec_time_base': '1/48000',
#   'codec_type': 'audio',
#   'disposition': {'attached_pic': 0,
#                   'clean_effects': 0,
#                   'comment': 0,
#                   'default': 1,
#                   'dub': 0,
#                   'forced': 0,
#                   'hearing_impaired': 0,
#                   'karaoke': 0,
#                   'lyrics': 0,
#                   'original': 0,
#                   'timed_thumbnails': 0,
#                   'visual_impaired': 0},
#   'duration': '305.173333',
#   'duration_ts': 14648320,
#   'index': 1,
#   'max_bit_rate': '48000',
#   'nb_frames': '14305',
#   'profile': 'LC',
#   'r_frame_rate': '0/0',
#   'sample_fmt': 'fltp',
#   'sample_rate': '48000',
#   'start_pts': 0,
#   'start_time': '0.000000',
#   'tags': {'creation_time': '2024-12-11T10:59:19.000000Z',
#            'handler_name': '\x0bGoPro AAC  ',
#            'language': 'eng',
#            'timecode': '10:59:19:15'},
#   'time_base': '1/48000'},
#  {'avg_frame_rate': '90000/3600',
#   'codec_tag': '0x64636d74',
#   'codec_tag_string': 'tmcd',
#   'codec_type': 'data',
#   'disposition': {'attached_pic': 0,
#                   'clean_effects': 0,
#                   'comment': 0,
#                   'default': 1,
#                   'dub': 0,
#                   'forced': 0,
#                   'hearing_impaired': 0,
#                   'karaoke': 0,
#                   'lyrics': 0,
#                   'original': 0,
#                   'timed_thumbnails': 0,
#                   'visual_impaired': 0},
#   'duration': '305.200000',
#   'duration_ts': 27468000,
#   'index': 2,
#   'nb_frames': '1',
#   'r_frame_rate': '0/0',
#   'start_pts': 0,
#   'start_time': '0.000000',
#   'tags': {'creation_time': '2024-12-11T10:59:19.000000Z',
#            'handler_name': '\x0bGoPro TCD  ',
#            'language': 'eng',
#            'timecode': '10:59:19:15'},
#   'time_base': '1/90000'},
#  {'avg_frame_rate': '0/0',
#   'bit_rate': '46505',
#   'codec_long_name': 'binary data',
#   'codec_name': 'bin_data',
#   'codec_tag': '0x646d7067',
#   'codec_tag_string': 'gpmd',
#   'codec_type': 'data',
#   'disposition': {'attached_pic': 0,
#                   'clean_effects': 0,
#                   'comment': 0,
#                   'default': 1,
#                   'dub': 0,
#                   'forced': 0,
#                   'hearing_impaired': 0,
#                   'karaoke': 0,
#                   'lyrics': 0,
#                   'original': 0,
#                   'timed_thumbnails': 0,
#                   'visual_impaired': 0},
#   'duration': '305.200000',
#   'duration_ts': 305200,
#   'index': 3,
#   'nb_frames': '294',
#   'r_frame_rate': '0/0',
#   'start_pts': 0,
#   'start_time': '0.000000',
#   'tags': {'creation_time': '2024-12-11T10:59:19.000000Z',
#            'handler_name': '\x0bGoPro MET  ',
#            'language': 'eng'},
#   'time_base': '1/1000'}]

# %%
metadata[0]['side_data_list'][0]['rotation']
# Out:
# -180
